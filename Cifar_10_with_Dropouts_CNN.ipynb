# %% [markdown]
# <a href="https://colab.research.google.com/github/AbhiSinha0987/AbhiSinha0987/blob/main/Cifar_10_with_Dropouts_CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import libraries
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D
import numpy as np
import os
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# batch, classes, epochs
batch_size = 32
num_classes = 10
epochs = 50

# %%
# The data, split between train and test sets:
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 3s 0us/step
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples

# %%
# plotting some random 10 images
class_names = ['airplane','automobile','bird','cat','deer',
               'dog','frog','horse','ship','truck']

fig = plt.figure(figsize=(8,3))
for i in range(num_classes):
    ax = fig.add_subplot(2, 5, 1 + i, xticks=[], yticks=[])
    idx = np.where(y_train[:]==i)[0]
    features_idx = x_train[idx,::]
    img_num = np.random.randint(features_idx.shape[0])
    im = (features_idx[img_num,::])
    ax.set_title(class_names[i])
    plt.imshow(im)
plt.show()

# %%
# Convert class vectors to binary class matrices.
y_train = tf.keras.utils.to_categorical(y_train, num_classes)
y_test = tf.keras.utils.to_categorical(y_test, num_classes)

# %%
# model architecture
model = Sequential()
model.add(Conv2D(32, (3, 3), padding='same',
                 input_shape=x_train.shape[1:]))
model.add(Activation('relu'))
model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes))
model.add(Activation('softmax'))

# %%
# summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 32)        896
# _________________________________________________________________
# activation (Activation)      (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 30, 30, 32)        9248
# _________________________________________________________________
# activation_1 (Activation)    (None, 30, 30, 32)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 15, 15, 64)        18496
# _________________________________________________________________
# activation_2 (Activation)    (None, 15, 15, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 13, 13, 64)        36928
# _________________________________________________________________
# activation_3 (Activation)    (None, 13, 13, 64)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 2304)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               1180160
# _________________________________________________________________
# activation_4 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                5130
# _________________________________________________________________
# activation_5 (Activation)    (None, 10)                0
# =================================================================
# Total params: 1,250,858
# Trainable params: 1,250,858
# Non-trainable params: 0
# _________________________________________________________________

# %%
# compile the model
model.compile(loss='categorical_crossentropy',
              optimizer='sgd',
              metrics=['accuracy'])

# convert to float, normalise the data
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

# %%
# train 
model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              shuffle=True)
# Out:
# Epoch 1/50
# 1563/1563 [==============================] - 40s 5ms/step - loss: 2.0930 - accuracy: 0.2219 - val_loss: 1.8406 - val_accuracy: 0.3502
# Epoch 2/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.7805 - accuracy: 0.3562 - val_loss: 1.5972 - val_accuracy: 0.4200
# Epoch 3/50
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.6059 - accuracy: 0.4150 - val_loss: 1.4838 - val_accuracy: 0.4671
# Epoch 4/50
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.4876 - accuracy: 0.4600 - val_loss: 1.3921 - val_accuracy: 0.4995
# Epoch 5/50
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.3998 - accuracy: 0.4932 - val_loss: 1.3495 - val_accuracy: 0.5108
# Epoch 6/50
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.3278 - accuracy: 0.5217 - val_loss: 1.2809 - val_accuracy: 0.5448
# Epoch 7/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.2611 - accuracy: 0.5473 - val_loss: 1.2328 - val_accuracy: 0.5727
# Epoch 8/50
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.1999 - accuracy: 0.5738 - val_loss: 1.1009 - val_accuracy: 0.6082
# Epoch 9/50
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.1410 - accuracy: 0.5950 - val_loss: 1.0361 - val_accuracy: 0.6349
# Epoch 10/50
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.0966 - accuracy: 0.6108 - val_loss: 0.9877 - val_accuracy: 0.6558
# Epoch 11/50
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.0518 - accuracy: 0.6268 - val_loss: 0.9501 - val_accuracy: 0.6729
# Epoch 12/50
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.0103 - accuracy: 0.6434 - val_loss: 0.9237 - val_accuracy: 0.6786
# Epoch 13/50
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.9722 - accuracy: 0.6593 - val_loss: 0.9123 - val_accuracy: 0.6816
# Epoch 14/50
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.9400 - accuracy: 0.6677 - val_loss: 0.9044 - val_accuracy: 0.6816
# Epoch 15/50
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.9097 - accuracy: 0.6780 - val_loss: 0.8350 - val_accuracy: 0.7133
# Epoch 16/50
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.8807 - accuracy: 0.6887 - val_loss: 0.8588 - val_accuracy: 0.7050
# Epoch 17/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.8579 - accuracy: 0.6966 - val_loss: 0.8240 - val_accuracy: 0.7154
# Epoch 18/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.8314 - accuracy: 0.7082 - val_loss: 0.7907 - val_accuracy: 0.7258
# Epoch 19/50
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.8046 - accuracy: 0.7176 - val_loss: 0.7652 - val_accuracy: 0.7349
# Epoch 20/50
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.7875 - accuracy: 0.7222 - val_loss: 0.7404 - val_accuracy: 0.7428
# Epoch 21/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.7693 - accuracy: 0.7285 - val_loss: 0.7409 - val_accuracy: 0.7454
# Epoch 22/50
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.7487 - accuracy: 0.7344 - val_loss: 0.7381 - val_accuracy: 0.7439
# Epoch 23/50
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.7313 - accuracy: 0.7441 - val_loss: 0.7028 - val_accuracy: 0.7555
# Epoch 24/50
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.7100 - accuracy: 0.7498 - val_loss: 0.7130 - val_accuracy: 0.7515
# Epoch 25/50
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.6993 - accuracy: 0.7520 - val_loss: 0.6990 - val_accuracy: 0.7590
# Epoch 26/50
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.6825 - accuracy: 0.7568 - val_loss: 0.7026 - val_accuracy: 0.7512
# Epoch 27/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.6710 - accuracy: 0.7620 - val_loss: 0.6652 - val_accuracy: 0.7678
# Epoch 28/50
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.6538 - accuracy: 0.7696 - val_loss: 0.6946 - val_accuracy: 0.7603
# Epoch 29/50
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.6400 - accuracy: 0.7748 - val_loss: 0.6641 - val_accuracy: 0.7675
# Epoch 30/50
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.6262 - accuracy: 0.7785 - val_loss: 0.6671 - val_accuracy: 0.7681
# Epoch 31/50
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.6133 - accuracy: 0.7834 - val_loss: 0.6560 - val_accuracy: 0.7743
# Epoch 32/50
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.6012 - accuracy: 0.7873 - val_loss: 0.6419 - val_accuracy: 0.7780
# Epoch 33/50
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.5929 - accuracy: 0.7888 - val_loss: 0.6501 - val_accuracy: 0.7728
# Epoch 34/50
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.5774 - accuracy: 0.7942 - val_loss: 0.6477 - val_accuracy: 0.7771
# Epoch 35/50
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.5702 - accuracy: 0.7964 - val_loss: 0.6290 - val_accuracy: 0.7796
# Epoch 36/50
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.5552 - accuracy: 0.8029 - val_loss: 0.6362 - val_accuracy: 0.7834
# Epoch 37/50
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.5449 - accuracy: 0.8066 - val_loss: 0.6211 - val_accuracy: 0.7876
# Epoch 38/50
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.5360 - accuracy: 0.8099 - val_loss: 0.6548 - val_accuracy: 0.7756
# Epoch 39/50
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.5247 - accuracy: 0.8133 - val_loss: 0.6113 - val_accuracy: 0.7892
# Epoch 40/50
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.5117 - accuracy: 0.8171 - val_loss: 0.6114 - val_accuracy: 0.7920
# Epoch 41/50
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.5044 - accuracy: 0.8207 - val_loss: 0.6112 - val_accuracy: 0.7894
# Epoch 42/50
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.4962 - accuracy: 0.8228 - val_loss: 0.6067 - val_accuracy: 0.7906
# Epoch 43/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.4823 - accuracy: 0.8273 - val_loss: 0.6101 - val_accuracy: 0.7915
# Epoch 44/50
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.4744 - accuracy: 0.8305 - val_loss: 0.6137 - val_accuracy: 0.7896
# Epoch 45/50
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.4625 - accuracy: 0.8344 - val_loss: 0.6100 - val_accuracy: 0.7929
# Epoch 46/50
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.4530 - accuracy: 0.8381 - val_loss: 0.5897 - val_accuracy: 0.7975
# Epoch 47/50
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.4495 - accuracy: 0.8391 - val_loss: 0.6164 - val_accuracy: 0.7915
# Epoch 48/50
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.4372 - accuracy: 0.8437 - val_loss: 0.6443 - val_accuracy: 0.7836
# Epoch 49/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.4378 - accuracy: 0.8430 - val_loss: 0.5971 - val_accuracy: 0.7955
# Epoch 50/50
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.4223 - accuracy: 0.8491 - val_loss: 0.5982 - val_accuracy: 0.7960

# %% [markdown]
# Result: After 50 epochs, the difference between training and validation accuracy is low but the training is slow as compared to the model with batch normalization.
